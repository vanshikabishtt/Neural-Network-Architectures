# %% [markdown]
# # Implement POS tagging on a text corpus using an NLP library (like NLTK or SpaCy). Analyze the grammatical structure of sentences using syntactic/dependency parsing.

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
text = """
I saw her in the rightest way
Looking like Anne Hathaway
Laughing while she hit her pen
And coughed, and coughed
And then, she came up to my knees
Begging, "Baby, would you please?
Do the things you said you'd do to me, to me?"
Oh, won't you kiss me on the mouth and love me like a sailor?
And when you get a taste, can you tell me what's my flavor?
I don't believe in God, but I believe that you're my savior
My mom says that she's worried, but I'm covered in His favor
And when we're getting dirty, I forget all that is wrong
I sleep so I can see you 'cause I hate to wait so long
I sleep so I can see you and I hate to wait so long
She took my fingers to her mouth
The kind of thing that makes you proud
That nothing else had ever
Worked out, worked out
And maybe I tried other things
But nothing can capture the sting
Of the venom she's gonna spit out right now
Oh, won't you kiss me on the mouth and love me like a sailor?
When you get a taste, can you tell me what's my flavor?
I don't believe in God, but I believe that you're my savior
I know that you've been worried, but you're dripping in my favor
And when we're getting dirty, I forget all that is wrong
I sleep so I can see you 'cause I hate to wait so long
I sleep so that I can see you and I hate to wait so long
And we can run away to the walls inside your house
I can be the cat, baby, you can be the mouse
And we can laugh off things that we know nothing about
We can go forever until you wanna sit it out
"""

# %%
doc=nlp(text)

# %%
for token in doc:
    print(f"{token.text:15}  POS: {token.pos_:10}  TAG: {token.tag_:10}  DEP: {token.dep_}  Description: {spacy.explain(token.tag_)}")
# Out:
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# saw              POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# her              POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# rightest         POS: ADJ         TAG: JJS         DEP: amod  Description: adjective, superlative
# way              POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Looking          POS: VERB        TAG: VBG         DEP: advcl  Description: verb, gerund or present participle
# like             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Anne             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Hathaway         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Laughing         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# while            POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# she              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# hit              POS: VERB        TAG: VBD         DEP: advcl  Description: verb, past tense
# her              POS: PRON        TAG: PRP         DEP: poss  Description: pronoun, personal
# pen              POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# And              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# coughed          POS: VERB        TAG: VBN         DEP: conj  Description: verb, past participle
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# coughed          POS: VERB        TAG: VBD         DEP: conj  Description: verb, past tense
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# And              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# then             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# she              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# came             POS: VERB        TAG: VBD         DEP: ccomp  Description: verb, past tense
# up               POS: ADP         TAG: RP          DEP: prt  Description: adverb, particle
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# my               POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# knees            POS: NOUN        TAG: NNS         DEP: compound  Description: noun, plural
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Begging          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# "                POS: PUNCT       TAG: ``          DEP: punct  Description: opening quotation mark
# Baby             POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# would            POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# please           POS: VERB        TAG: VB          DEP: conj  Description: verb, base form
# ?                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Do               POS: AUX         TAG: VB          DEP: aux  Description: verb, base form
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# things           POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# said             POS: VERB        TAG: VBD         DEP: relcl  Description: verb, past tense
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# 'd               POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# do               POS: VERB        TAG: VB          DEP: ccomp  Description: verb, base form
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# me               POS: PRON        TAG: PRP         DEP: pobj  Description: pronoun, personal
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# me               POS: PRON        TAG: PRP         DEP: pobj  Description: pronoun, personal
# ?                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# "                POS: PUNCT       TAG: ``          DEP: punct  Description: opening quotation mark
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Oh               POS: INTJ        TAG: UH          DEP: intj  Description: interjection
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# wo               POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# n't              POS: PART        TAG: RB          DEP: neg  Description: adverb
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# kiss             POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# me               POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# mouth            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# love             POS: VERB        TAG: VB          DEP: conj  Description: verb, base form
# me               POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# like             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# sailor           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ?                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# And              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# when             POS: SCONJ       TAG: WRB         DEP: advmod  Description: wh-adverb
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# get              POS: VERB        TAG: VBP         DEP: advcl  Description: verb, non-3rd person singular present
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# taste            POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# tell             POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# me               POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# what             POS: PRON        TAG: WP          DEP: attr  Description: wh-pronoun, personal
# 's               POS: AUX         TAG: VBZ         DEP: ccomp  Description: verb, 3rd person singular present
# my               POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# flavor           POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# ?                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# do               POS: AUX         TAG: VBP         DEP: aux  Description: verb, non-3rd person singular present
# n't              POS: PART        TAG: RB          DEP: neg  Description: adverb
# believe          POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# God              POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# but              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# believe          POS: VERB        TAG: VBP         DEP: conj  Description: verb, non-3rd person singular present
# that             POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# 're              POS: AUX         TAG: VBP         DEP: ccomp  Description: verb, non-3rd person singular present
# my               POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# savior           POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# My               POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# mom              POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# says             POS: VERB        TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# that             POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# she              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# 's               POS: AUX         TAG: VBZ         DEP: ccomp  Description: verb, 3rd person singular present
# worried          POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# but              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# I                POS: PRON        TAG: PRP         DEP: nsubjpass  Description: pronoun, personal
# 'm               POS: AUX         TAG: VBP         DEP: auxpass  Description: verb, non-3rd person singular present
# covered          POS: VERB        TAG: VBN         DEP: conj  Description: verb, past participle
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# His              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# favor            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# And              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# when             POS: SCONJ       TAG: WRB         DEP: advmod  Description: wh-adverb
# we               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# 're              POS: AUX         TAG: VBP         DEP: aux  Description: verb, non-3rd person singular present
# getting          POS: VERB        TAG: VBG         DEP: advcl  Description: verb, gerund or present participle
# dirty            POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# forget           POS: VERB        TAG: VBP         DEP: conj  Description: verb, non-3rd person singular present
# all              POS: DET         TAG: PDT         DEP: dobj  Description: predeterminer
# that             POS: PRON        TAG: WDT         DEP: nsubj  Description: wh-determiner
# is               POS: AUX         TAG: VBZ         DEP: relcl  Description: verb, 3rd person singular present
# wrong            POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# sleep            POS: VERB        TAG: VBP         DEP: ROOT  Description: verb, non-3rd person singular present
# so               POS: ADV         TAG: RB          DEP: mark  Description: adverb
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# see              POS: VERB        TAG: VB          DEP: advcl  Description: verb, base form
# you              POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# 'cause           POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# hate             POS: VERB        TAG: VBP         DEP: advcl  Description: verb, non-3rd person singular present
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# wait             POS: VERB        TAG: VB          DEP: xcomp  Description: verb, base form
# so               POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# long             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# sleep            POS: VERB        TAG: VBP         DEP: ccomp  Description: verb, non-3rd person singular present
# so               POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# see              POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# you              POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# hate             POS: VERB        TAG: VBP         DEP: ROOT  Description: verb, non-3rd person singular present
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# wait             POS: VERB        TAG: VB          DEP: xcomp  Description: verb, base form
# so               POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# long             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# She              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# took             POS: VERB        TAG: VBD         DEP: ccomp  Description: verb, past tense
# my               POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# fingers          POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# her              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# mouth            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# The              POS: DET         TAG: DT          DEP: det  Description: determiner
# kind             POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# thing            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# that             POS: PRON        TAG: WDT         DEP: nsubj  Description: wh-determiner
# makes            POS: VERB        TAG: VBZ         DEP: relcl  Description: verb, 3rd person singular present
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# proud            POS: ADJ         TAG: JJ          DEP: ccomp  Description: adjective (English), other noun-modifier (Chinese)
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# That             POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# nothing          POS: PRON        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# else             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# had              POS: AUX         TAG: VBD         DEP: aux  Description: verb, past tense
# ever             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Worked           POS: VERB        TAG: VBN         DEP: ccomp  Description: verb, past participle
# out              POS: ADP         TAG: RP          DEP: prt  Description: adverb, particle
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# worked           POS: VERB        TAG: VBD         DEP: advcl  Description: verb, past tense
# out              POS: ADP         TAG: RP          DEP: prt  Description: adverb, particle
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# And              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# maybe            POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# tried            POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# other            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# things           POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# But              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# nothing          POS: PRON        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# capture          POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# sting            POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# venom            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# she              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# 's               POS: AUX         TAG: VBZ         DEP: aux  Description: verb, 3rd person singular present
# gon              POS: VERB        TAG: VBG         DEP: relcl  Description: verb, gerund or present participle
# na               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# spit             POS: VERB        TAG: VB          DEP: xcomp  Description: verb, base form
# out              POS: ADP         TAG: RP          DEP: prt  Description: adverb, particle
# right            POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# now              POS: ADV         TAG: RB          DEP: advmod  Description: adverb
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Oh               POS: INTJ        TAG: UH          DEP: intj  Description: interjection
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# wo               POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# n't              POS: PART        TAG: RB          DEP: neg  Description: adverb
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# kiss             POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# me               POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# mouth            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# love             POS: VERB        TAG: VB          DEP: conj  Description: verb, base form
# me               POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# like             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# sailor           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ?                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# When             POS: SCONJ       TAG: WRB         DEP: advmod  Description: wh-adverb
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# get              POS: VERB        TAG: VBP         DEP: advcl  Description: verb, non-3rd person singular present
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# taste            POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# tell             POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# me               POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# what             POS: PRON        TAG: WP          DEP: attr  Description: wh-pronoun, personal
# 's               POS: AUX         TAG: VBZ         DEP: ccomp  Description: verb, 3rd person singular present
# my               POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# flavor           POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# ?                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# do               POS: AUX         TAG: VBP         DEP: aux  Description: verb, non-3rd person singular present
# n't              POS: PART        TAG: RB          DEP: neg  Description: adverb
# believe          POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# God              POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# but              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# believe          POS: VERB        TAG: VBP         DEP: conj  Description: verb, non-3rd person singular present
# that             POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# 're              POS: AUX         TAG: VBP         DEP: ccomp  Description: verb, non-3rd person singular present
# my               POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# savior           POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# know             POS: VERB        TAG: VBP         DEP: ROOT  Description: verb, non-3rd person singular present
# that             POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# 've              POS: AUX         TAG: VBP         DEP: aux  Description: verb, non-3rd person singular present
# been             POS: AUX         TAG: VBN         DEP: ccomp  Description: verb, past participle
# worried          POS: VERB        TAG: VBN         DEP: acomp  Description: verb, past participle
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# but              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# 're              POS: AUX         TAG: VBP         DEP: conj  Description: verb, non-3rd person singular present
# dripping         POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# my               POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# favor            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# And              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# when             POS: SCONJ       TAG: WRB         DEP: advmod  Description: wh-adverb
# we               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# 're              POS: AUX         TAG: VBP         DEP: aux  Description: verb, non-3rd person singular present
# getting          POS: VERB        TAG: VBG         DEP: advcl  Description: verb, gerund or present participle
# dirty            POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# forget           POS: VERB        TAG: VBP         DEP: conj  Description: verb, non-3rd person singular present
# all              POS: DET         TAG: PDT         DEP: dobj  Description: predeterminer
# that             POS: PRON        TAG: WDT         DEP: nsubj  Description: wh-determiner
# is               POS: AUX         TAG: VBZ         DEP: relcl  Description: verb, 3rd person singular present
# wrong            POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# sleep            POS: VERB        TAG: VBP         DEP: ROOT  Description: verb, non-3rd person singular present
# so               POS: ADV         TAG: RB          DEP: mark  Description: adverb
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# see              POS: VERB        TAG: VB          DEP: advcl  Description: verb, base form
# you              POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# 'cause           POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# hate             POS: VERB        TAG: VBP         DEP: advcl  Description: verb, non-3rd person singular present
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# wait             POS: VERB        TAG: VB          DEP: xcomp  Description: verb, base form
# so               POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# long             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# sleep            POS: VERB        TAG: VBP         DEP: ccomp  Description: verb, non-3rd person singular present
# so               POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# that             POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# see              POS: VERB        TAG: VB          DEP: advcl  Description: verb, base form
# you              POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# hate             POS: VERB        TAG: VBP         DEP: ROOT  Description: verb, non-3rd person singular present
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# wait             POS: VERB        TAG: VB          DEP: xcomp  Description: verb, base form
# so               POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# long             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# And              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# we               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# run              POS: VERB        TAG: VB          DEP: ccomp  Description: verb, base form
# away             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# walls            POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# inside           POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# your             POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# house            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# I                POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# be               POS: AUX         TAG: VB          DEP: ccomp  Description: verb, base form
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# cat              POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# baby             POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# be               POS: AUX         TAG: VB          DEP: ROOT  Description: verb, base form
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# mouse            POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# And              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# we               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# laugh            POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# off              POS: ADP         TAG: RP          DEP: prt  Description: adverb, particle
# things           POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# that             POS: PRON        TAG: WDT         DEP: pobj  Description: wh-determiner
# we               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# know             POS: VERB        TAG: VBP         DEP: relcl  Description: verb, non-3rd person singular present
# nothing          POS: PRON        TAG: NN          DEP: dobj  Description: noun, singular or mass
# about            POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# We               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# go               POS: VERB        TAG: VB          DEP: pcomp  Description: verb, base form
# forever          POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# until            POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# you              POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# wanna            POS: VERB        TAG: VBP         DEP: advcl  Description: verb, non-3rd person singular present
# sit              POS: VERB        TAG: VBP         DEP: xcomp  Description: verb, non-3rd person singular present
# it               POS: PRON        TAG: PRP         DEP: dobj  Description: pronoun, personal
# out              POS: ADP         TAG: RP          DEP: prt  Description: adverb, particle
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace

# %%
for token in doc:
    print(f"{token.text:12} <--{token.dep_:10}-- {token.head.text}")
# Out:
#             <--dep       -- saw
# I            <--nsubj     -- saw
# saw          <--ROOT      -- saw
# her          <--dobj      -- saw
# in           <--prep      -- saw
# the          <--det       -- way
# rightest     <--amod      -- way
# way          <--pobj      -- in
#
#             <--dep       -- way
# Looking      <--advcl     -- saw
# like         <--prep      -- Looking
# Anne         <--compound  -- Hathaway
# Hathaway     <--compound  -- Laughing
#
#             <--dep       -- Hathaway
# Laughing     <--pobj      -- like
# while        <--mark      -- hit
# she          <--nsubj     -- hit
# hit          <--advcl     -- Looking
# her          <--poss      -- pen
# pen          <--dobj      -- hit
#
#             <--dep       -- pen
# And          <--cc        -- hit
# coughed      <--conj      -- hit
# ,            <--punct     -- saw
# and          <--cc        -- saw
# coughed      <--conj      -- saw
#
#             <--dep       -- coughed
# And          <--cc        -- saw
# then         <--advmod    -- came
# ,            <--punct     -- came
# she          <--nsubj     -- came
# came         <--ccomp     -- please
# up           <--prt       -- came
# to           <--prep      -- came
# my           <--poss      -- knees
# knees        <--compound  -- Begging
#
#             <--dep       -- knees
# Begging      <--pobj      -- to
# ,            <--punct     -- Begging
# "            <--punct     -- Begging
# Baby         <--appos     -- Begging
# ,            <--punct     -- please
# would        <--aux       -- please
# you          <--nsubj     -- please
# please       <--conj      -- saw
# ?            <--punct     -- saw
#
#             <--dep       -- ?
# Do           <--aux       -- kiss
# the          <--det       -- things
# things       <--dobj      -- Do
# you          <--nsubj     -- said
# said         <--relcl     -- things
# you          <--nsubj     -- do
# 'd           <--aux       -- do
# do           <--ccomp     -- said
# to           <--prep      -- do
# me           <--pobj      -- to
# ,            <--punct     -- Do
# to           <--prep      -- Do
# me           <--pobj      -- to
# ?            <--punct     -- Do
# "            <--punct     -- Do
#
#             <--dep       -- "
# Oh           <--intj      -- kiss
# ,            <--punct     -- kiss
# wo           <--aux       -- kiss
# n't          <--neg       -- kiss
# you          <--nsubj     -- kiss
# kiss         <--ROOT      -- kiss
# me           <--dobj      -- kiss
# on           <--prep      -- kiss
# the          <--det       -- mouth
# mouth        <--pobj      -- on
# and          <--cc        -- kiss
# love         <--conj      -- kiss
# me           <--dobj      -- love
# like         <--prep      -- love
# a            <--det       -- sailor
# sailor       <--pobj      -- like
# ?            <--punct     -- kiss
#
#             <--dep       -- ?
# And          <--cc        -- tell
# when         <--advmod    -- get
# you          <--nsubj     -- get
# get          <--advcl     -- tell
# a            <--det       -- taste
# taste        <--dobj      -- get
# ,            <--punct     -- tell
# can          <--aux       -- tell
# you          <--nsubj     -- tell
# tell         <--ROOT      -- tell
# me           <--dobj      -- tell
# what         <--attr      -- 's
# 's           <--ccomp     -- tell
# my           <--poss      -- flavor
# flavor       <--nsubj     -- 's
# ?            <--punct     -- tell
#
#             <--dep       -- ?
# I            <--nsubj     -- believe
# do           <--aux       -- believe
# n't          <--neg       -- believe
# believe      <--ROOT      -- believe
# in           <--prep      -- believe
# God          <--pobj      -- in
# ,            <--punct     -- believe
# but          <--cc        -- believe
# I            <--nsubj     -- believe
# believe      <--conj      -- believe
# that         <--mark      -- 're
# you          <--nsubj     -- 're
# 're          <--ccomp     -- believe
# my           <--poss      -- savior
# savior       <--attr      -- 're
#
#             <--dep       -- savior
# My           <--poss      -- mom
# mom          <--nsubj     -- says
# says         <--ROOT      -- says
# that         <--mark      -- 's
# she          <--nsubj     -- 's
# 's           <--ccomp     -- says
# worried      <--acomp     -- 's
# ,            <--punct     -- says
# but          <--cc        -- says
# I            <--nsubjpass -- covered
# 'm           <--auxpass   -- covered
# covered      <--conj      -- says
# in           <--prep      -- covered
# His          <--poss      -- favor
# favor        <--pobj      -- in
#
#             <--dep       -- favor
# And          <--cc        -- covered
# when         <--advmod    -- getting
# we           <--nsubj     -- getting
# 're          <--aux       -- getting
# getting      <--advcl     -- forget
# dirty        <--acomp     -- getting
# ,            <--punct     -- forget
# I            <--nsubj     -- forget
# forget       <--conj      -- covered
# all          <--dobj      -- forget
# that         <--nsubj     -- is
# is           <--relcl     -- all
# wrong        <--acomp     -- is
#
#             <--dep       -- wrong
# I            <--nsubj     -- sleep
# sleep        <--ROOT      -- sleep
# so           <--mark      -- see
# I            <--nsubj     -- see
# can          <--aux       -- see
# see          <--advcl     -- sleep
# you          <--dobj      -- see
# 'cause       <--mark      -- hate
# I            <--nsubj     -- hate
# hate         <--advcl     -- see
# to           <--aux       -- wait
# wait         <--xcomp     -- hate
# so           <--advmod    -- long
# long         <--advmod    -- wait
#
#             <--dep       -- long
# I            <--nsubj     -- sleep
# sleep        <--ccomp     -- see
# so           <--advmod    -- see
# I            <--nsubj     -- see
# can          <--aux       -- see
# see          <--ROOT      -- see
# you          <--dobj      -- see
# and          <--cc        -- hate
# I            <--nsubj     -- hate
# hate         <--ROOT      -- hate
# to           <--aux       -- wait
# wait         <--xcomp     -- hate
# so           <--advmod    -- long
# long         <--advmod    -- wait
#
#             <--dep       -- long
# She          <--nsubj     -- took
# took         <--ccomp     -- hate
# my           <--poss      -- fingers
# fingers      <--dobj      -- took
# to           <--prep      -- took
# her          <--poss      -- mouth
# mouth        <--pobj      -- to
#
#             <--dep       -- mouth
# The          <--det       -- kind
# kind         <--appos     -- mouth
# of           <--prep      -- kind
# thing        <--pobj      -- of
# that         <--nsubj     -- makes
# makes        <--relcl     -- kind
# you          <--nsubj     -- proud
# proud        <--ccomp     -- makes
#
#             <--dep       -- proud
# That         <--mark      -- Worked
# nothing      <--nsubj     -- Worked
# else         <--advmod    -- nothing
# had          <--aux       -- Worked
# ever         <--advmod    -- Worked
#
#             <--dep       -- ever
# Worked       <--ccomp     -- proud
# out          <--prt       -- Worked
# ,            <--punct     -- Worked
# worked       <--advcl     -- took
# out          <--prt       -- worked
#
#             <--dep       -- out
# And          <--cc        -- tried
# maybe        <--advmod    -- tried
# I            <--nsubj     -- tried
# tried        <--ROOT      -- tried
# other        <--amod      -- things
# things       <--dobj      -- tried
#
#             <--dep       -- things
# But          <--cc        -- capture
# nothing      <--nsubj     -- capture
# can          <--aux       -- capture
# capture      <--ROOT      -- capture
# the          <--det       -- sting
# sting        <--dobj      -- capture
#
#             <--dep       -- sting
# Of           <--prep      -- sting
# the          <--det       -- venom
# venom        <--pobj      -- Of
# she          <--nsubj     -- gon
# 's           <--aux       -- gon
# gon          <--relcl     -- venom
# na           <--aux       -- spit
# spit         <--xcomp     -- gon
# out          <--prt       -- spit
# right        <--advmod    -- now
# now          <--advmod    -- spit
#
#             <--dep       -- now
# Oh           <--intj      -- kiss
# ,            <--punct     -- kiss
# wo           <--aux       -- kiss
# n't          <--neg       -- kiss
# you          <--nsubj     -- kiss
# kiss         <--ROOT      -- kiss
# me           <--dobj      -- kiss
# on           <--prep      -- kiss
# the          <--det       -- mouth
# mouth        <--pobj      -- on
# and          <--cc        -- kiss
# love         <--conj      -- kiss
# me           <--dobj      -- love
# like         <--prep      -- love
# a            <--det       -- sailor
# sailor       <--pobj      -- like
# ?            <--punct     -- kiss
#
#             <--dep       -- ?
# When         <--advmod    -- get
# you          <--nsubj     -- get
# get          <--advcl     -- tell
# a            <--det       -- taste
# taste        <--dobj      -- get
# ,            <--punct     -- tell
# can          <--aux       -- tell
# you          <--nsubj     -- tell
# tell         <--ROOT      -- tell
# me           <--dobj      -- tell
# what         <--attr      -- 's
# 's           <--ccomp     -- tell
# my           <--poss      -- flavor
# flavor       <--nsubj     -- 's
# ?            <--punct     -- tell
#
#             <--dep       -- ?
# I            <--nsubj     -- believe
# do           <--aux       -- believe
# n't          <--neg       -- believe
# believe      <--ROOT      -- believe
# in           <--prep      -- believe
# God          <--pobj      -- in
# ,            <--punct     -- believe
# but          <--cc        -- believe
# I            <--nsubj     -- believe
# believe      <--conj      -- believe
# that         <--mark      -- 're
# you          <--nsubj     -- 're
# 're          <--ccomp     -- believe
# my           <--poss      -- savior
# savior       <--attr      -- 're
#
#             <--dep       -- savior
# I            <--nsubj     -- know
# know         <--ROOT      -- know
# that         <--mark      -- been
# you          <--nsubj     -- been
# 've          <--aux       -- been
# been         <--ccomp     -- know
# worried      <--acomp     -- been
# ,            <--punct     -- know
# but          <--cc        -- know
# you          <--nsubj     -- 're
# 're          <--conj      -- know
# dripping     <--acomp     -- 're
# in           <--prep      -- dripping
# my           <--poss      -- favor
# favor        <--pobj      -- in
#
#             <--dep       -- favor
# And          <--cc        -- 're
# when         <--advmod    -- getting
# we           <--nsubj     -- getting
# 're          <--aux       -- getting
# getting      <--advcl     -- forget
# dirty        <--acomp     -- getting
# ,            <--punct     -- forget
# I            <--nsubj     -- forget
# forget       <--conj      -- 're
# all          <--dobj      -- forget
# that         <--nsubj     -- is
# is           <--relcl     -- all
# wrong        <--acomp     -- is
#
#             <--dep       -- wrong
# I            <--nsubj     -- sleep
# sleep        <--ROOT      -- sleep
# so           <--mark      -- see
# I            <--nsubj     -- see
# can          <--aux       -- see
# see          <--advcl     -- sleep
# you          <--dobj      -- see
# 'cause       <--mark      -- hate
# I            <--nsubj     -- hate
# hate         <--advcl     -- see
# to           <--aux       -- wait
# wait         <--xcomp     -- hate
# so           <--advmod    -- long
# long         <--advmod    -- wait
#
#             <--dep       -- long
# I            <--nsubj     -- sleep
# sleep        <--ccomp     -- see
# so           <--mark      -- see
# that         <--mark      -- see
# I            <--nsubj     -- see
# can          <--aux       -- see
# see          <--advcl     -- sleep
# you          <--dobj      -- see
# and          <--cc        -- hate
# I            <--nsubj     -- hate
# hate         <--ROOT      -- hate
# to           <--aux       -- wait
# wait         <--xcomp     -- hate
# so           <--advmod    -- long
# long         <--advmod    -- wait
#
#             <--dep       -- long
# And          <--cc        -- run
# we           <--nsubj     -- run
# can          <--aux       -- run
# run          <--ccomp     -- be
# away         <--advmod    -- run
# to           <--prep      -- away
# the          <--det       -- walls
# walls        <--pobj      -- to
# inside       <--prep      -- walls
# your         <--poss      -- house
# house        <--pobj      -- inside
#
#             <--dep       -- house
# I            <--nsubj     -- be
# can          <--aux       -- be
# be           <--ccomp     -- run
# the          <--det       -- cat
# cat          <--attr      -- be
# ,            <--punct     -- cat
# baby         <--appos     -- cat
# ,            <--punct     -- be
# you          <--nsubj     -- be
# can          <--aux       -- be
# be           <--ROOT      -- be
# the          <--det       -- mouse
# mouse        <--attr      -- be
#
#             <--dep       -- mouse
# And          <--cc        -- laugh
# we           <--nsubj     -- laugh
# can          <--aux       -- laugh
# laugh        <--ROOT      -- laugh
# off          <--prt       -- laugh
# things       <--dobj      -- laugh
# that         <--pobj      -- about
# we           <--nsubj     -- know
# know         <--relcl     -- things
# nothing      <--dobj      -- know
# about        <--prep      -- nothing
#
#             <--dep       -- about
# We           <--nsubj     -- go
# can          <--aux       -- go
# go           <--pcomp     -- about
# forever      <--advmod    -- go
# until        <--mark      -- wanna
# you          <--nsubj     -- wanna
# wanna        <--advcl     -- go
# sit          <--xcomp     -- wanna
# it           <--dobj      -- sit
# out          <--prt       -- sit
#
#             <--dep       -- out

# %%
for sent in doc.sents:
    print("Sentence:", sent.text)
    for token in sent:
        print(f"  {token.text:15} {token.pos_:10} {token.dep_:10} --> {token.head.text}")
    print()
# Out:
# Sentence:
# I saw her in the rightest way
# Looking like Anne Hathaway
# Laughing while she hit her pen
# And coughed, and coughed
# And then, she came up to my knees
# Begging, "Baby, would you please?
#
#
#                SPACE      dep        --> saw
#   I               PRON       nsubj      --> saw
#   saw             VERB       ROOT       --> saw
#   her             PRON       dobj       --> saw
#   in              ADP        prep       --> saw
#   the             DET        det        --> way
#   rightest        ADJ        amod       --> way
#   way             NOUN       pobj       --> in
#
#                SPACE      dep        --> way
#   Looking         VERB       advcl      --> saw
#   like            ADP        prep       --> Looking
#   Anne            PROPN      compound   --> Hathaway
#   Hathaway        PROPN      compound   --> Laughing
#
#                SPACE      dep        --> Hathaway
#   Laughing        NOUN       pobj       --> like
#   while           SCONJ      mark       --> hit
#   she             PRON       nsubj      --> hit
#   hit             VERB       advcl      --> Looking
#   her             PRON       poss       --> pen
#   pen             NOUN       dobj       --> hit
#
#                SPACE      dep        --> pen
#   And             CCONJ      cc         --> hit
#   coughed         VERB       conj       --> hit
#   ,               PUNCT      punct      --> saw
#   and             CCONJ      cc         --> saw
#   coughed         VERB       conj       --> saw
#
#                SPACE      dep        --> coughed
#   And             CCONJ      cc         --> saw
#   then            ADV        advmod     --> came
#   ,               PUNCT      punct      --> came
#   she             PRON       nsubj      --> came
#   came            VERB       ccomp      --> please
#   up              ADP        prt        --> came
#   to              ADP        prep       --> came
#   my              PRON       poss       --> knees
#   knees           NOUN       compound   --> Begging
#
#                SPACE      dep        --> knees
#   Begging         NOUN       pobj       --> to
#   ,               PUNCT      punct      --> Begging
#   "               PUNCT      punct      --> Begging
#   Baby            PROPN      appos      --> Begging
#   ,               PUNCT      punct      --> please
#   would           AUX        aux        --> please
#   you             PRON       nsubj      --> please
#   please          VERB       conj       --> saw
#   ?               PUNCT      punct      --> saw
#
#                SPACE      dep        --> ?
#
# Sentence: Do the things you said you'd do to me, to me?"
# Oh, won't you kiss me on the mouth and love me like a sailor?
#
#   Do              AUX        aux        --> kiss
#   the             DET        det        --> things
#   things          NOUN       dobj       --> Do
#   you             PRON       nsubj      --> said
#   said            VERB       relcl      --> things
#   you             PRON       nsubj      --> do
#   'd              AUX        aux        --> do
#   do              VERB       ccomp      --> said
#   to              ADP        prep       --> do
#   me              PRON       pobj       --> to
#   ,               PUNCT      punct      --> Do
#   to              ADP        prep       --> Do
#   me              PRON       pobj       --> to
#   ?               PUNCT      punct      --> Do
#   "               PUNCT      punct      --> Do
#
#                SPACE      dep        --> "
#   Oh              INTJ       intj       --> kiss
#   ,               PUNCT      punct      --> kiss
#   wo              AUX        aux        --> kiss
#   n't             PART       neg        --> kiss
#   you             PRON       nsubj      --> kiss
#   kiss            VERB       ROOT       --> kiss
#   me              PRON       dobj       --> kiss
#   on              ADP        prep       --> kiss
#   the             DET        det        --> mouth
#   mouth           NOUN       pobj       --> on
#   and             CCONJ      cc         --> kiss
#   love            VERB       conj       --> kiss
#   me              PRON       dobj       --> love
#   like            ADP        prep       --> love
#   a               DET        det        --> sailor
#   sailor          NOUN       pobj       --> like
#   ?               PUNCT      punct      --> kiss
#
#                SPACE      dep        --> ?
#
# Sentence: And when you get a taste, can you tell me what's my flavor?
#
#   And             CCONJ      cc         --> tell
#   when            SCONJ      advmod     --> get
#   you             PRON       nsubj      --> get
#   get             VERB       advcl      --> tell
#   a               DET        det        --> taste
#   taste           NOUN       dobj       --> get
#   ,               PUNCT      punct      --> tell
#   can             AUX        aux        --> tell
#   you             PRON       nsubj      --> tell
#   tell            VERB       ROOT       --> tell
#   me              PRON       dobj       --> tell
#   what            PRON       attr       --> 's
#   's              AUX        ccomp      --> tell
#   my              PRON       poss       --> flavor
#   flavor          NOUN       nsubj      --> 's
#   ?               PUNCT      punct      --> tell
#
#                SPACE      dep        --> ?
#
# Sentence: I don't believe in God, but I believe that you're my savior
#
#   I               PRON       nsubj      --> believe
#   do              AUX        aux        --> believe
#   n't             PART       neg        --> believe
#   believe         VERB       ROOT       --> believe
#   in              ADP        prep       --> believe
#   God             PROPN      pobj       --> in
#   ,               PUNCT      punct      --> believe
#   but             CCONJ      cc         --> believe
#   I               PRON       nsubj      --> believe
#   believe         VERB       conj       --> believe
#   that            SCONJ      mark       --> 're
#   you             PRON       nsubj      --> 're
#   're             AUX        ccomp      --> believe
#   my              PRON       poss       --> savior
#   savior          NOUN       attr       --> 're
#
#                SPACE      dep        --> savior
#
# Sentence: My mom says that she's worried, but I'm covered in His favor
# And when we're getting dirty, I forget all that is wrong
#
#   My              PRON       poss       --> mom
#   mom             NOUN       nsubj      --> says
#   says            VERB       ROOT       --> says
#   that            SCONJ      mark       --> 's
#   she             PRON       nsubj      --> 's
#   's              AUX        ccomp      --> says
#   worried         ADJ        acomp      --> 's
#   ,               PUNCT      punct      --> says
#   but             CCONJ      cc         --> says
#   I               PRON       nsubjpass  --> covered
#   'm              AUX        auxpass    --> covered
#   covered         VERB       conj       --> says
#   in              ADP        prep       --> covered
#   His             PRON       poss       --> favor
#   favor           NOUN       pobj       --> in
#
#                SPACE      dep        --> favor
#   And             CCONJ      cc         --> covered
#   when            SCONJ      advmod     --> getting
#   we              PRON       nsubj      --> getting
#   're             AUX        aux        --> getting
#   getting         VERB       advcl      --> forget
#   dirty           ADJ        acomp      --> getting
#   ,               PUNCT      punct      --> forget
#   I               PRON       nsubj      --> forget
#   forget          VERB       conj       --> covered
#   all             DET        dobj       --> forget
#   that            PRON       nsubj      --> is
#   is              AUX        relcl      --> all
#   wrong           ADJ        acomp      --> is
#
#                SPACE      dep        --> wrong
#
# Sentence: I sleep so I can see you 'cause I hate to wait so long
# I sleep
#   I               PRON       nsubj      --> sleep
#   sleep           VERB       ROOT       --> sleep
#   so              ADV        mark       --> see
#   I               PRON       nsubj      --> see
#   can             AUX        aux        --> see
#   see             VERB       advcl      --> sleep
#   you             PRON       dobj       --> see
#   'cause          SCONJ      mark       --> hate
#   I               PRON       nsubj      --> hate
#   hate            VERB       advcl      --> see
#   to              PART       aux        --> wait
#   wait            VERB       xcomp      --> hate
#   so              ADV        advmod     --> long
#   long            ADV        advmod     --> wait
#
#                SPACE      dep        --> long
#   I               PRON       nsubj      --> sleep
#   sleep           VERB       ccomp      --> see
#
# Sentence: so I can see you
#   so              ADV        advmod     --> see
#   I               PRON       nsubj      --> see
#   can             AUX        aux        --> see
#   see             VERB       ROOT       --> see
#   you             PRON       dobj       --> see
#
# Sentence: and I hate to wait so long
# She took my fingers to her mouth
# The kind of thing that makes you proud
# That nothing else had ever
# Worked out, worked out
#
#   and             CCONJ      cc         --> hate
#   I               PRON       nsubj      --> hate
#   hate            VERB       ROOT       --> hate
#   to              PART       aux        --> wait
#   wait            VERB       xcomp      --> hate
#   so              ADV        advmod     --> long
#   long            ADV        advmod     --> wait
#
#                SPACE      dep        --> long
#   She             PRON       nsubj      --> took
#   took            VERB       ccomp      --> hate
#   my              PRON       poss       --> fingers
#   fingers         NOUN       dobj       --> took
#   to              ADP        prep       --> took
#   her             PRON       poss       --> mouth
#   mouth           NOUN       pobj       --> to
#
#                SPACE      dep        --> mouth
#   The             DET        det        --> kind
#   kind            NOUN       appos      --> mouth
#   of              ADP        prep       --> kind
#   thing           NOUN       pobj       --> of
#   that            PRON       nsubj      --> makes
#   makes           VERB       relcl      --> kind
#   you             PRON       nsubj      --> proud
#   proud           ADJ        ccomp      --> makes
#
#                SPACE      dep        --> proud
#   That            SCONJ      mark       --> Worked
#   nothing         PRON       nsubj      --> Worked
#   else            ADV        advmod     --> nothing
#   had             AUX        aux        --> Worked
#   ever            ADV        advmod     --> Worked
#
#                SPACE      dep        --> ever
#   Worked          VERB       ccomp      --> proud
#   out             ADP        prt        --> Worked
#   ,               PUNCT      punct      --> Worked
#   worked          VERB       advcl      --> took
#   out             ADP        prt        --> worked
#
#                SPACE      dep        --> out
#
# Sentence: And maybe I tried other things
#
#   And             CCONJ      cc         --> tried
#   maybe           ADV        advmod     --> tried
#   I               PRON       nsubj      --> tried
#   tried           VERB       ROOT       --> tried
#   other           ADJ        amod       --> things
#   things          NOUN       dobj       --> tried
#
#                SPACE      dep        --> things
#
# Sentence: But nothing can capture the sting
# Of the venom she's gonna spit out right now
#
#   But             CCONJ      cc         --> capture
#   nothing         PRON       nsubj      --> capture
#   can             AUX        aux        --> capture
#   capture         VERB       ROOT       --> capture
#   the             DET        det        --> sting
#   sting           NOUN       dobj       --> capture
#
#                SPACE      dep        --> sting
#   Of              ADP        prep       --> sting
#   the             DET        det        --> venom
#   venom           NOUN       pobj       --> Of
#   she             PRON       nsubj      --> gon
#   's              AUX        aux        --> gon
#   gon             VERB       relcl      --> venom
#   na              PART       aux        --> spit
#   spit            VERB       xcomp      --> gon
#   out             ADP        prt        --> spit
#   right           ADV        advmod     --> now
#   now             ADV        advmod     --> spit
#
#                SPACE      dep        --> now
#
# Sentence: Oh, won't you kiss me on the mouth and love me like a sailor?
#
#   Oh              INTJ       intj       --> kiss
#   ,               PUNCT      punct      --> kiss
#   wo              AUX        aux        --> kiss
#   n't             PART       neg        --> kiss
#   you             PRON       nsubj      --> kiss
#   kiss            VERB       ROOT       --> kiss
#   me              PRON       dobj       --> kiss
#   on              ADP        prep       --> kiss
#   the             DET        det        --> mouth
#   mouth           NOUN       pobj       --> on
#   and             CCONJ      cc         --> kiss
#   love            VERB       conj       --> kiss
#   me              PRON       dobj       --> love
#   like            ADP        prep       --> love
#   a               DET        det        --> sailor
#   sailor          NOUN       pobj       --> like
#   ?               PUNCT      punct      --> kiss
#
#                SPACE      dep        --> ?
#
# Sentence: When you get a taste, can you tell me what's my flavor?
#
#   When            SCONJ      advmod     --> get
#   you             PRON       nsubj      --> get
#   get             VERB       advcl      --> tell
#   a               DET        det        --> taste
#   taste           NOUN       dobj       --> get
#   ,               PUNCT      punct      --> tell
#   can             AUX        aux        --> tell
#   you             PRON       nsubj      --> tell
#   tell            VERB       ROOT       --> tell
#   me              PRON       dobj       --> tell
#   what            PRON       attr       --> 's
#   's              AUX        ccomp      --> tell
#   my              PRON       poss       --> flavor
#   flavor          NOUN       nsubj      --> 's
#   ?               PUNCT      punct      --> tell
#
#                SPACE      dep        --> ?
#
# Sentence: I don't believe in God, but I believe that you're my savior
#
#   I               PRON       nsubj      --> believe
#   do              AUX        aux        --> believe
#   n't             PART       neg        --> believe
#   believe         VERB       ROOT       --> believe
#   in              ADP        prep       --> believe
#   God             PROPN      pobj       --> in
#   ,               PUNCT      punct      --> believe
#   but             CCONJ      cc         --> believe
#   I               PRON       nsubj      --> believe
#   believe         VERB       conj       --> believe
#   that            SCONJ      mark       --> 're
#   you             PRON       nsubj      --> 're
#   're             AUX        ccomp      --> believe
#   my              PRON       poss       --> savior
#   savior          NOUN       attr       --> 're
#
#                SPACE      dep        --> savior
#
# Sentence: I know that you've been worried, but you're dripping in my favor
# And when we're getting dirty, I forget all that is wrong
#
#   I               PRON       nsubj      --> know
#   know            VERB       ROOT       --> know
#   that            SCONJ      mark       --> been
#   you             PRON       nsubj      --> been
#   've             AUX        aux        --> been
#   been            AUX        ccomp      --> know
#   worried         VERB       acomp      --> been
#   ,               PUNCT      punct      --> know
#   but             CCONJ      cc         --> know
#   you             PRON       nsubj      --> 're
#   're             AUX        conj       --> know
#   dripping        ADJ        acomp      --> 're
#   in              ADP        prep       --> dripping
#   my              PRON       poss       --> favor
#   favor           NOUN       pobj       --> in
#
#                SPACE      dep        --> favor
#   And             CCONJ      cc         --> 're
#   when            SCONJ      advmod     --> getting
#   we              PRON       nsubj      --> getting
#   're             AUX        aux        --> getting
#   getting         VERB       advcl      --> forget
#   dirty           ADJ        acomp      --> getting
#   ,               PUNCT      punct      --> forget
#   I               PRON       nsubj      --> forget
#   forget          VERB       conj       --> 're
#   all             DET        dobj       --> forget
#   that            PRON       nsubj      --> is
#   is              AUX        relcl      --> all
#   wrong           ADJ        acomp      --> is
#
#                SPACE      dep        --> wrong
#
# Sentence: I sleep so I can see you 'cause I hate to wait so long
# I sleep so that I can see you
#   I               PRON       nsubj      --> sleep
#   sleep           VERB       ROOT       --> sleep
#   so              ADV        mark       --> see
#   I               PRON       nsubj      --> see
#   can             AUX        aux        --> see
#   see             VERB       advcl      --> sleep
#   you             PRON       dobj       --> see
#   'cause          SCONJ      mark       --> hate
#   I               PRON       nsubj      --> hate
#   hate            VERB       advcl      --> see
#   to              PART       aux        --> wait
#   wait            VERB       xcomp      --> hate
#   so              ADV        advmod     --> long
#   long            ADV        advmod     --> wait
#
#                SPACE      dep        --> long
#   I               PRON       nsubj      --> sleep
#   sleep           VERB       ccomp      --> see
#   so              SCONJ      mark       --> see
#   that            SCONJ      mark       --> see
#   I               PRON       nsubj      --> see
#   can             AUX        aux        --> see
#   see             VERB       advcl      --> sleep
#   you             PRON       dobj       --> see
#
# Sentence: and I hate to wait so long
#
#   and             CCONJ      cc         --> hate
#   I               PRON       nsubj      --> hate
#   hate            VERB       ROOT       --> hate
#   to              PART       aux        --> wait
#   wait            VERB       xcomp      --> hate
#   so              ADV        advmod     --> long
#   long            ADV        advmod     --> wait
#
#                SPACE      dep        --> long
#
# Sentence: And we can run away to the walls inside your house
# I can be the cat, baby, you can be the mouse
#
#   And             CCONJ      cc         --> run
#   we              PRON       nsubj      --> run
#   can             AUX        aux        --> run
#   run             VERB       ccomp      --> be
#   away            ADV        advmod     --> run
#   to              ADP        prep       --> away
#   the             DET        det        --> walls
#   walls           NOUN       pobj       --> to
#   inside          ADP        prep       --> walls
#   your            PRON       poss       --> house
#   house           NOUN       pobj       --> inside
#
#                SPACE      dep        --> house
#   I               PRON       nsubj      --> be
#   can             AUX        aux        --> be
#   be              AUX        ccomp      --> run
#   the             DET        det        --> cat
#   cat             NOUN       attr       --> be
#   ,               PUNCT      punct      --> cat
#   baby            NOUN       appos      --> cat
#   ,               PUNCT      punct      --> be
#   you             PRON       nsubj      --> be
#   can             AUX        aux        --> be
#   be              AUX        ROOT       --> be
#   the             DET        det        --> mouse
#   mouse           NOUN       attr       --> be
#
#                SPACE      dep        --> mouse
#
# Sentence: And we can laugh off things that we know nothing about
# We can go forever until you wanna sit it out
#
#   And             CCONJ      cc         --> laugh
#   we              PRON       nsubj      --> laugh
#   can             AUX        aux        --> laugh
#   laugh           VERB       ROOT       --> laugh
#   off             ADP        prt        --> laugh
#   things          NOUN       dobj       --> laugh
#   that            PRON       pobj       --> about
#   we              PRON       nsubj      --> know
#   know            VERB       relcl      --> things
#   nothing         PRON       dobj       --> know
#   about           ADP        prep       --> nothing
#
#                SPACE      dep        --> about
#   We              PRON       nsubj      --> go
#   can             AUX        aux        --> go
#   go              VERB       pcomp      --> about
#   forever         ADV        advmod     --> go
#   until           SCONJ      mark       --> wanna
#   you             PRON       nsubj      --> wanna
#   wanna           VERB       advcl      --> go
#   sit             VERB       xcomp      --> wanna
#   it              PRON       dobj       --> sit
#   out             ADP        prt        --> sit
#
#                SPACE      dep        --> out

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d0623793bb6d4c768acc93947aab8221-0" class="displacy" width="63575" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">saw</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">rightest</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">way</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Looking</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">like</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">Anne</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Hathaway</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Laughing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">while</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">hit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">pen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">And</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">coughed,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">coughed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">And</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">then,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">came</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">up</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5300">ADP</tspa
